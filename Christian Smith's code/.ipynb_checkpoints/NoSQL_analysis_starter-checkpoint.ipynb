# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %%
establishments.find({"scores.Hygiene":20})[0]
# Out:
# {'_id': ObjectId('6568ec85646a26d8d12659fe'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.27694, 'latitude': 50.769705},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
# ...

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene":20}

# Use count_documents to display the number of documents in the result
print(f"The number of documents with a Hygiene score of 20 is {establishments.count_documents(query)}")
results1=establishments.find(query)
# Display the first document in the results using pprint
pprint(results1[0])
# Out:
# The number of documents with a Hygiene score of 20 is 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6568ec85646a26d8d12659fe'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
results1_df = pd.DataFrame(results1)
# Display the number of rows in the DataFrame
len(results1_df.index)
# Display the first 10 rows of the DataFrame
results1_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6568ec85646a26d8d12659fe   110681                  0
# 1  6568ec85646a26d8d1265d7e   612039                  0
# 2  6568ec85646a26d8d1266082   730933                  0
# 3  6568ec85646a26d8d1266275   172735                  0
# 4  6568ec85646a26d8d126627f   172953                  0
# 5  6568ec85646a26d8d1266c23   512854                  0
# 6  6568ec85646a26d8d1266e46  1537089                  0
# 7  6568ec85646a26d8d126836d   155648                  0
# 8  6568ec85646a26d8d12687b5  1012883                  0
# 9  6568ec85646a26d8d1268fc2   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"RatingValue":{"$gte":4},"LocalAuthorityName":{"$regex":"London"}}

# Use count_documents to display the number of documents in the result
print(f"The number of establishments in London with a RatingValue greater or equal to 4 is {establishments.count_documents(query)}")
results2=establishments.find(query)
# Display the first document in the results using pprint
pprint(results2[0])
# Out:
# The number of establishments in London with a RatingValue greater or equal to 4 is 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6568ec85646a26d8d1267414'),
# ...

# %%
# Convert the result to a Pandas DataFrame
results2_df = pd.DataFrame(results2)
# Display the number of rows in the DataFrame
len(results2_df.index)
# Display the first 10 rows of the DataFrame
results2_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6568ec85646a26d8d1267414   621707                  0
# 1  6568ec85646a26d8d1267740  1130836                  0
# 2  6568ec85646a26d8d1268289   293783                  0
# 3  6568ec85646a26d8d1269089   294474                  0
# 4  6568ec85646a26d8d1269099  1315095                  0
# 5  6568ec85646a26d8d1269795   294900                  0
# 6  6568ec86646a26d8d126b8a4   293756                  0
# 7  6568ec86646a26d8d126bc62   878523                  0
# 8  6568ec86646a26d8d126bc7d   293772                  0
# 9  6568ec86646a26d8d126bc7e   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 50.769705
longitude = 0.27694

query = {"RatingValue":5,"geocode.latitude":{"$lt":(latitude+degree_search),"$gt":(latitude-degree_search)},
        "geocode.longitude":{"$lt":(longitude+degree_search),"$gt":(longitude-degree_search)}}
sort =  [("scores.Hygiene",1)]
results3=list(establishments.find(query).sort(sort).limit(5))
# Print the results
pprint(list(results3))
# Out:
# [{'AddressLine1': '60-62 Terminus Road',
#   'AddressLine2': 'Eastbourne',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'BusinessName': 'Buffet Time',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4613.645080026569,
#   'FHRSID': 131009,
#   'LocalAuthorityBusinessID': '62341',
#   'LocalAuthorityCode': '102',
#   'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#   'LocalAuthorityName': 'Eastbourne',
#   'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN21 3LX',
#   'RatingDate': '2022-06-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6568ec85646a26d8d126596c'),
#   'geocode': {'latitude': 50.768608, 'longitude': 0.282418},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/131009',
# ...

# %%
# Convert result to Pandas DataFrame
results3_df = pd.DataFrame(results3)
results3_df
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  6568ec85646a26d8d126596c  131009                  0
# 1  6568ec85646a26d8d126599e  667987                  0
# 2  6568ec85646a26d8d12657e1  131328                  0
# 3  6568ec85646a26d8d12657e5  148038                  0
# 4  6568ec85646a26d8d12657ff   58779                  0
#
#   LocalAuthorityBusinessID                  BusinessName  \
# 0                    62341                   Buffet Time
# 1                    74908                  Bella's Cafe
# 2                    62760          Carpet Gardens Kiosk
# 3                     9210           Howard Square Kiosk
# 4                     1302  Best Western Lansdowne Hotel
#
#                         BusinessType  BusinessTypeID         AddressLine1  \
# 0            Restaurant/Cafe/Canteen               1  60-62 Terminus Road
# 1            Restaurant/Cafe/Canteen               1        Terminus Road
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
matchquery = {"$match":{"scores.Hygiene":0}}
sort = {"$sort":{"count":-1}}
groupquery = {"$group":{"_id":"$LocalAuthorityName",
                       "count":{"$sum":1}}}
pipeline = [matchquery,groupquery,sort]
results4=list(establishments.aggregate(pipeline))
results4
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542},
#  {'_id': 'Colchester', 'count': 498},
#  {'_id': 'Tunbridge Wells', 'count': 491},
#  {'_id': 'Folkestone and Hythe', 'count': 480},
#  {'_id': 'Eastbourne', 'count': 478},
#  {'_id': 'Hastings', 'count': 464},
#  {'_id': 'Bromley', 'count': 460},
#  {'_id': 'Ashford', 'count': 427},
#  {'_id': 'Havering', 'count': 397},
#  {'_id': 'Dartford', 'count': 383},
#  {'_id': 'Braintree', 'count': 382},
#  {'_id': 'Basildon', 'count': 362},
#  {'_id': 'Gravesham', 'count': 339},
#  {'_id': 'Tonbridge and Malling', 'count': 325},
#  {'_id': 'Thurrock', 'count': 313},
#  {'_id': 'Barking and Dagenham', 'count': 301},
# ...

# %%
# Print the number of documents in the result
print(f"There are {len(results4)} documents in the result")
# Print the first 10 results
pprint(results4[0:10])
# Out:
# There are 55 documents in the result
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
results4_df=pd.DataFrame(results4)
results4_df
# Display the number of rows in the DataFrame
len(results4_df.index)
# Display the first 10 rows of the DataFrame
results4_df.head(10)
# Out:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
